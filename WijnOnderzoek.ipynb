# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd


df1 = pd.read_csv('redwine.csv',sep=';', encoding = 'unicode_escape')
df1.head()
# Out:
#      id   country                                        description  \
# 0   242  Portugal  This is a spicy, rich, smooth wine, immediatel...
# 1  1332  Portugal  Firm tannins give a dry character, Black fruit...
# 2  1366  Portugal  Firmly tannic and dry, this is a textured wine...
# 3  2367  Portugal  From a small sub-region of Lisboa, this stylis...
# 4  2424  Portugal  From a small sub-region of Lisboa, this stylis...
#
#               designation  points  price  province        taster_name  \
# 0  Quinta das Setencostas      87    8.0  Alenquer     Joe Czerwinski
# 1  Quinta das Setencostas      86    NaN  Alenquer         Roger Voss
# 2  Quinta das Setencostas      87    8.0  Alenquer       Paul Gregutt
# 3  Quinta das Setencostas      90   11.0  Alenquer     Virginie Boone
# 4  Quinta das Setencostas      90   11.0  Alenquer  Michael Schachner
#
#                                                title         variety  ...  \
# ...
